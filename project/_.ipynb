# %% [markdown]
# # Project for submission

# %% [markdown]
# ## AI usage
#
#
# ## Log
#
#
# ## Links
#
# - Github: https://github.com/Satheris/IND320_SMAA
# - Streamlit app: https://ind320smaa-2eg32uba6uhmrknkwtxzar.streamlit.app/

# %% [markdown]
# ## Coding
#
# ### Imports

# %%
import pandas as pd
import plotly
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading data

# %%
meteodata = pd.read_csv('data/open-meteo-subset.csv')
meteodata.head()
# Out:
#                time  temperature_2m (°C)  precipitation (mm)  \
# 0  2020-01-01T00:00                 -2.2                 0.1
# 1  2020-01-01T01:00                 -2.2                 0.0
# 2  2020-01-01T02:00                 -2.3                 0.0
# 3  2020-01-01T03:00                 -2.3                 0.0
# 4  2020-01-01T04:00                 -2.7                 0.0
#
#    wind_speed_10m (m/s)  wind_gusts_10m (m/s)  wind_direction_10m (°)
# 0                   9.6                  21.3                     284
# 1                  10.6                  23.0                     282
# 2                  11.0                  23.5                     284
# 3                  10.6                  23.3                     284
# 4                  10.6                  22.8                     284

# %% [markdown]
# ### Plotting data

# %%
meteodata.describe()
# Out:
#        temperature_2m (°C)  precipitation (mm)  wind_speed_10m (m/s)  \
# count          8760.000000         8760.000000           8760.000000
# mean             -0.394909            0.222854              3.661689
# std               6.711903            0.493747              2.253210
# min             -19.300000            0.000000              0.100000
# 25%              -4.900000            0.000000              1.800000
# 50%              -1.000000            0.000000              3.300000
# 75%               4.100000            0.200000              5.100000
# max              19.900000            5.800000             13.600000
#
#        wind_gusts_10m (m/s)  wind_direction_10m (°)
# count           8760.000000             8760.000000
# mean               8.300719              212.209589
# std                5.098909               91.371980
# min                0.200000                0.000000
# 25%                4.500000              128.000000
# ...

# %%
meteodata['precipitation (mm)'].plot(title='Precipitation (mm)', x=meteodata['time'], rot=90)
# Out:
# <Axes: title={'center': 'Precipitation (mm)'}>

# %%
meteodata['temperature_2m (°C)'].plot(title='Temperature')
# Out:
# <Axes: title={'center': 'Temperature'}>

# %%
meteodata['wind_direction_10m (°)'].plot(title='Wind direction')
# Out:
# <Axes: title={'center': 'Wind direction'}>

# %%
meteodata['wind_gusts_10m (m/s)'].plot(title='Wind gusts')
# Out:
# <Axes: title={'center': 'Wind gusts'}>

# %%
meteodata['wind_speed_10m (m/s)'].plot(title='Wind speed')
# Out:
# <Axes: title={'center': 'Wind speed'}>

# %%
meteodata.plot(x='time', rot=90)
# Out:
# <Axes: xlabel='time'>
